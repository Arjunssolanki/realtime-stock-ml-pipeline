# %%
pip install kafka-python-ng yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
[ Live Yahoo Finance API ] 
         │
         ▼
[ Local Python Producer Script (VS Code) ]
         │ (Streams live stock ticker ticks)
         ▼
[ Apache Kafka Broker (AWS EC2 Instance) ]
         │
         ▼
[ Real-Time ML Consumer Script (VS Code) ] 
         │ ──► Reads streaming ticks from Kafka
         │ ──► Feeds data into a Trained Predictive ML Model (LSTM / Random Forest)
         │ ──► Generates Next-Minute Price Forecasts / Buy-Sell Signals
         ▼
[ Amazon S3 Data Lake ] ──► Stores both Raw Ticks AND ML Predictions side-by-side
🧠
